# %% [markdown]
# # **Quest 11: Biological Warfare**
#
# ![Header image](./imgs/image_quest_11.svg)
# [<img src="./imgs/instagram.svg" alt="My SVG" width="15" height="15"><small>_Monika Lipińska_</small>](https://www.instagram.com/monli_art/)
#
# # Part I
#
# The next tournament competition takes place in a very peculiar location, the **Biological Weapons District**. Unconventional and cunning warfare methods are a specialty of the Knights of the Order.
#
# One such method involves breeding **Omnivorous Termites**. Their strength lies not only in their ability to eat literally anything — including the enemy's weaponry — but also in their rapid population growth rate. Just a few suitable specimens sent near the enemy's castle can ensure that, within a short time, no trace of it will remain.
#
# However, for breeding purposes, it is crucial to consciously control the population size. Through years of work, the life cycle of the entire species has been identified. All individuals have been categorized, and for each category, the appearance of the next generation has been determined.
#
# Each individual converts into a new generation every day. You have noted down all conversions (_your notes_). The new individuals are also capable of converting the following day, so the overall population can grow extremely quickly — but it can also be very accurately predicted. This is precisely what the next tournament task involves.
#
# You start with a single **A** category termite, and you have to calculate the overall population after **4 days**, based on the conversion notes.
#
# ---
#
# ### Example
#
# Given the following notes:
#
# ```
# A:B,C
# B:C,A
# C:A
# ```
#
# You start with a single **A** termite.
#
# - **After the first day**, it converts into **B** and **C**, so the population is:
#   `B, C`
#
# - **After the second day**, each termite converts again, producing:
#   `C, A, A`
#   (population size: 3)
#
# - **After the third day**, the population becomes:
#   `A, B, C, B, C`
#   (population size: 5)
#
# - **After the fourth day**, the population becomes:
#   `B, C, C, A, A, C, A, A`
#   (population size: 8)
#
# ---
#
# ### Question
#
# **What will be the termite population count on the 4th day?**
#
# ```
#
# ```

# %%
from itertools import product
import re
from string import ascii_uppercase
from typing import Self

from more_itertools import first, last, one

from test_utilities import test

tests = [
    {
        "name": "Example",
        "notes": """
            A:B,C
            B:C,A
            C:A
        """,
        "expected": 8,
    },
]


@test(tests=tests[:])
def part_I(notes: str, days: int = 4, population=["A"]) -> int:
    growth = {
        first(l.strip().split(":")): last(l.split(":")).split(",")
        for l in notes.strip().splitlines()
    }

    for _ in range(days):
        population = [t1 for t in population for t1 in growth[t]]

    return len(population)
# Out:
# Test Example passed, for part_I.
# Success

# %%
with open("../inputs/everybody_codes_e2024_q11_p1.txt") as f:
    notes1 = f.read()

print(f"Part I: {part_I(notes1)}")
# Out:
# Part I: 46

# %% [markdown]
# # Part II
#
# The second round takes place in an even more hostile environment, the **Infestation Lab**. This time, however, the Knights have perfected their Omnivorous Termites, and they come in a new strain with distinct conversion patterns.
#
# These new termites, starting from a single category **Z** termite, grow in a completely different way than the previous strain, but the general rules remain the same. Each termite converts into a new generation every day, and the newly created individuals also convert on the following day.
#
# Your task is to predict the population count on the **10th day**, based on the new conversion notes provided for this strain.
#
# ---
#
# ### Question
#
# **What will be the termite population count on the 10th day?**

# %%
with open("../inputs/everybody_codes_e2024_q11_p2.txt") as f:
    notes2 = f.read()

print(f"PartII: {part_I(notes2, days=10, population=['Z'])}")
# Out:
# PartII: 388281

# %% [markdown]
# # Part III
#
# The final round presents a new, intricate challenge. A newly engineered strain of termites has been developed for an upcoming combat mission. The knights must now investigate how the **initial termite types** affect the overall population after **20 days** of growth.
#
# Your task is to determine **which initial termite types** will yield the **largest** and **smallest** populations on the 20th day, and then calculate the **difference** between these two population sizes.
#
# ---
#
# ### Example
#
# Given the following notes:
#
# ```
# A:B,C
# B:C,A,A
# C:A
# ```
#
# - Starting with a single **A** termite results in a population of **330205** on day 20.
# - Starting with a single **B** termite results in a population of **444092** on day 20.
# - Starting with a single **C** termite results in a population of **175277** on day 20.
#
# To compute the population difference, subtract the smallest value from the largest:
#
# $$
# 444092 - 175277 = 268815
# $$
#
# ---
#
# ### Question
#
# **What is the population difference on the 20th day?**
#
# ```
#
# ```

# %%
from functools import cache

from more_itertools import minmax

from test_utilities import test

tests = [
    {
        "name": "Example",
        "notes": """
            A:B,C
            B:C,A,A
            C:A
        """,
        "expected": 268815,
    },
]


@test(tests=tests[:])
def part_III(notes: str, days: int = 20) -> int:
    @cache
    def live(days: int, termite: str) -> int:
        if days == 0:
            return 1
        return sum(live(days - 1, t) for t in growth[termite])

    growth = {
        first(l.strip().split(":")): last(l.split(":")).split(",")
        for l in notes.strip().splitlines()
    }

    min_p, max_p = minmax(live(days, p) for p in growth.keys())

    return max_p - min_p
# Out:
# Test Example passed, for part_III.
# Success

# %%
with open("../inputs/everybody_codes_e2024_q11_p3.txt") as f:
    notes3 = f.read()


print(f"Part III {part_III(notes3)}")
# Out:
# Part III 1022297563096

# %% [markdown]
# ![happy](./imgs/happy_quack.svg)
